# %%
import os 
import pickle as pkl
import scipy.io as sio 

import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = sio.loadmat('/tmp/pytest-of-versag/pytest-current/data/val_sim/50LM.mat')
data['speed'].max(), data['torque'].max()
# Out:
# (2077.5267247456804, 53.037667576346934)

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'voltage_d', 'voltage_q', 'speed', 'current_d', 'current_q', 'torque', 'time'])

# %%
plt.plot( data['time'][0], data['speed'][0])

# %%
data2 = sio.loadmat('../../../datasets/data/train_raw/LM10.mat')
data2['speed'].max(), data2['torque'].max()
# Out:
# (85.27974442651737, 121.1181640625)

# %%
plt.plot(data2['time'][0], data2['speed'][0])
