# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import scipy.io as sio 

import pickle as pkl

fin = open('../../../datasets/benchmark/train/0.pkl','rb')
data = pkl.load(fin)
fin.close()
a
plt.figure(figsize=(20,10))
plt.plot(data['time'], data['reference_torque_act'])
plt.plot(data['time'], data['torque'])
plt.show()
plt.figure(figsize=(20,10))
plt.plot(data['time'], data['reference_speed_rad'])
plt.plot(data['time'], data['speed'])
plt.show()
plt.figure(figsize=(20,10))
plt.plot(data['time'], data['reference_torque_act'])
