# %%
import pickle as pkl 
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fin = open('../../../datasets/benchmark/train/14.pkl','rb')
data = pkl.load(fin)
fin.close()

# %%
plt.plot(data['time'],data['reference_speed_rad'])

# %%
plt.plot(data['time'],data['reference_torque_act'])

# %%
plt.plot(data['time'],data['voltage_d'])
plt.plot(data['time'],data['voltage_q'])

# %%
plt.plot(data['time'],data['current_d'])
plt.plot(data['time'],data['current_q'])

# %%
plt.plot(data['time'], data['speed'])

# %%
plt.plot(data['time'],data['torque'])

# %%
plt.plot(data['time'], data['statorPuls'])
