# %%
import scipy.io as sio
from scipy import signal
from scipy.stats import pearsonr
from scipy.spatial.distance import euclidean
from sklearn.metrics import mean_squared_error as mse
import os
import numpy as np

from sklearn import preprocessing
from tftb.processing import Scalogram
from tftb.generators import fmconst
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
current = sio.loadmat('../../datasets/CS2018_12_14/Current.mat')
voltage = sio.loadmat('../../datasets/CS2018_12_14/Voltage.mat')
stator_plus = sio.loadmat('../../datasets/CS2018_12_14/StatorPuls.mat')
speed = sio.loadmat('../../datasets/CS2018_12_14/Speed.mat')
torque = sio.loadmat('../../datasets/CS2018_12_14/Torque.mat')

# %%
dataset = np.hstack((voltage['Voltage'], stator_plus['StatorPuls'], speed['Speed'], current['Current'], torque['Torque']))
dataset.shape
# Out:
# (240001, 7)

# %%
dataset_scaled = np.copy(dataset)

# %%
current1_scaler = preprocessing.MinMaxScaler(feature_range=[0,1])
current1_scaler.fit(dataset_scaled[:,4:5])

current2_scaler = preprocessing.MinMaxScaler(feature_range=[0,1])
current2_scaler.fit(dataset_scaled[:,5:6])

torque_scaler = preprocessing.MinMaxScaler(feature_range=[0,1])
torque_scaler.fit(dataset_scaled[:,6:7])

voltage1_scaler = preprocessing.MinMaxScaler(feature_range=[0,1])
voltage1_scaler.fit(dataset_scaled[:,0:1])

voltage2_scaler = preprocessing.MinMaxScaler(feature_range=[0,1])
voltage2_scaler.fit(dataset_scaled[:,1:2])

statorpuls_scaler = preprocessing.MinMaxScaler(feature_range=[0,1])
statorpuls_scaler.fit(dataset_scaled[:,2:3])

speed_scaler = preprocessing.MinMaxScaler(feature_range=[0,1])
speed_scaler.fit(dataset_scaled[:,3:4])
# Out:
# MinMaxScaler(copy=True, feature_range=[0, 1])

# %%
v1 = dataset[:,0]
v2 = dataset[:,1]
sp = dataset[:,2]
s = dataset[:,3]
c1 = dataset[:,4]
c2 = dataset[:,5]
t = dataset[:,6]
time = [x * 0.005 for x in range(dataset.shape[0])]

# %%
st = 10
en = 12
start = int(st / 0.005)
end = int(en / 0.005)

# %%
plt.plot(time[start:end], v1[start:end])
plt.legend()
plt.ylabel('Voltage u_d (V)')
plt.xlabel('Time (s)')
plt.tight_layout()
plt.savefig('images/raw_voltage_d_vs_time_' + str(st) + '_' + str(en) + '.pdf',dpi=500,quality=100)
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(time[start:end], v2[start:end])
plt.legend()
plt.ylabel('Voltage u_q (V)')
plt.xlabel('Time (s)')
plt.tight_layout()
plt.savefig('images/raw_voltage_q_vs_time_' + str(st) + '_' + str(en) + '.pdf',dpi=500,quality=100)
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(time[start:end], sp[start:end])
plt.legend()
plt.ylabel('Stator Pulse sp ')
plt.xlabel('Time (s)')
plt.tight_layout()
plt.savefig('images/raw_stator_pulse_vs_time_' + str(st) + '_' + str(en) + '.pdf',dpi=500,quality=100)
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(time[start:end], s[start:end])
plt.legend()
plt.ylabel('Speed w_s (rad/s)')
plt.xlabel('Time (s)')
plt.tight_layout()
plt.savefig('images/raw_speed_vs_time_' + str(st) + '_' + str(en) + '.pdf',dpi=500,quality=100)
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(time[start:end], c1[start:end])
plt.legend()
plt.ylabel('Current i_d (A)')
plt.xlabel('Time (s)')
plt.tight_layout()
plt.savefig('images/raw_current_d_vs_time_' + str(st) + '_' + str(en) + '.pdf',dpi=500,quality=100)
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(time[start:end], c2[start:end])
plt.legend()
plt.ylabel('Current i_q (A)')
plt.xlabel('Time (s)')
plt.tight_layout()
plt.savefig('images/raw_current_q_vs_time_' + str(st) + '_' + str(en) + '.pdf',dpi=500,quality=100)
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(time[start:end], t[start:end])
plt.legend()
plt.ylabel('Torque t (N-m)')
plt.xlabel('Time (s)')
plt.tight_layout()
plt.savefig('images/raw_torque_vs_time_' + str(st) + '_' + str(en) + '.pdf',dpi=500,quality=100)
# Out:
# No handles with labels found to put in legend.
