# %%
import os 
import pickle as pkl
import scipy.io as sio 

import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = sio.loadmat('/tmp/pytest-of-versag/pytest-current/data/val_sim/LM20_TorqueSteps.mat')
data['speed'].max() / 2 / np.pi, data['torque'].max() / 25 * 100
# Out:
# (392.93429362717853, 160.98069344631668)

# %%
plt.plot( data['time'][0], data['current_d'][0])

# %%
file = '../../../datasets//data/train_sim/0-100Hz.mat'
data = sio.loadmat(file)
print(data['speed'].max(), data['torque'].max())

plt.plot(data['time'][0], data['speed'][0])
plt.show()
plt.plot(data['time'][0], data['torque'][0] / 25 * 100)

# data['speed'] = data['speed'] / 2 / np.pi
data['torque'] = data['torque'] / 25 * 100
sio.savemat(file + '.new', data)
# Out:
# 639.0282649045675 46.560257372162866
