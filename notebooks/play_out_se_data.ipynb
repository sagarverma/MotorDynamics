# %%
import scipy.io as sio
import os
import numpy as np
from scipy.signal import resample
from sklearn import preprocessing

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
current = sio.loadmat('../datasets/DATACSdet_simulink_current_dq.mat')
voltage = sio.loadmat('../datasets/DATACSdet_simulink_voltage_dq.mat')
stator_plus = sio.loadmat('../datasets/DATACSdet_simulink_statorplus_dq.mat')
speed = sio.loadmat('../datasets/DATACSdet_simulink_speed_dq.mat')
torque = sio.loadmat('../datasets/DATACSdet_simulink_torque_dq.mat')

# %%
dataset = np.hstack((voltage['Voltage'], stator_plus['StatorPuls'], speed['Speed'], current['Current'], torque['Torque']))
scaler = preprocessing.MinMaxScaler(feature_range=[0,1])
scaler.fit(dataset)
dataset = scaler.transform(dataset)

# %%
# plt.plot(dataset[100:20000,0])
plt.plot(dataset[0:20000,0])
plt.plot(dataset[0:20000,1])
plt.savefig('../docs/pres2/images/voltages.png')

# %%
plt.plot(dataset[0:20000,2])
plt.savefig('../docs/pres2/images/stator_pulse.png')

# %%
plt.plot(dataset[0:20000,3])
plt.savefig('../docs/pres2/images/speed.png')

# %%
plt.plot(dataset[0:20000,4])
plt.plot(dataset[0:20000,5])
plt.savefig('../docs/pres2/images/current.png')

# %%
plt.plot(dataset[0:20000,6])
plt.savefig('../docs/pres2/images/torque.png')

# %%
# plt.plot(dataset[100:20000,0])
plt.plot(dataset[0:20000,1])
plt.plot(dataset[0:20000,2])
plt.savefig('../docs/pres2/images/voltage2_stator_pulse.png')

# %%
start = 2000
end = 2100

# %%
output_ann = np.load('../datasets/results_npy/SE_data_ann5_out.npy')
plt.plot(output_ann[0,start:end])
plt.plot(output_ann[1,start:end])
plt.show()
plt.plot(output_ann[2,start:end])
plt.plot(output_ann[3,start:end])
plt.show()
plt.plot(output_ann[4,start:end])
plt.plot(output_ann[5,start:end])
plt.show()

# %%
output_ann = np.load('../datasets/results_npy/SE_data_ann10_out.npy')
plt.plot(output_ann[0,start:end])
plt.plot(output_ann[1,start:end])
plt.show()
plt.plot(output_ann[2,start:end])
plt.plot(output_ann[3,start:end])
plt.show()
plt.plot(output_ann[4,start:end])
plt.plot(output_ann[5,start:end])
plt.show()

# %%
output_ann = np.load('../datasets/results_npy/SE_data_ann15_out.npy')
plt.plot(output_ann[0,start:end])
plt.plot(output_ann[1,start:end])
plt.show()
plt.plot(output_ann[2,start:end])
plt.plot(output_ann[3,start:end])
plt.show()
plt.plot(output_ann[4,start:end])
plt.plot(output_ann[5,start:end])
plt.show()

# %%
output_ann = np.load('../datasets/results_npy/SE_data_ann20_out.npy')
plt.plot(output_ann[0,start:end])
plt.plot(output_ann[1,start:end])
plt.show()
plt.plot(output_ann[2,start:end])
plt.plot(output_ann[3,start:end])
plt.show()
plt.plot(output_ann[4,start:end])
plt.plot(output_ann[5,start:end])
plt.show()

# %%
output_ann = np.load('../datasets/results_npy/SE_data_ann25_out.npy')
plt.plot(output_ann[0,start:end])
plt.plot(output_ann[1,start:end])
plt.show()
plt.plot(output_ann[2,start:end])
plt.plot(output_ann[3,start:end])
plt.show()
plt.plot(output_ann[4,start:end])
plt.plot(output_ann[5,start:end])
plt.show()

# %%
output_ann = np.load('../datasets/results_npy/SE_data_ann50_out.npy')
plt.plot(output_ann[0,start:end])
plt.plot(output_ann[1,start:end])
plt.show()
plt.plot(output_ann[2,start:end])
plt.plot(output_ann[3,start:end])
plt.show()
plt.plot(output_ann[4,start:end])
plt.plot(output_ann[5,start:end])
plt.show()

# %%
output_ann = np.load('../datasets/results_npy/SE_data_ann100_out.npy')
plt.plot(output_ann[0,start:end])
plt.plot(output_ann[1,start:end])
plt.show()
plt.plot(output_ann[2,start:end])
plt.plot(output_ann[3,start:end])
plt.show()
plt.plot(output_ann[4,start:end])
plt.plot(output_ann[5,start:end])
plt.show()

# %%
output_cnn = np.load('../datasets/results_npy/SE_data_cnn100_out.npy')
start = 0
end = 100
plt.plot(output_cnn[1,start:end])
plt.plot(output_cnn[0,start:end]) 
plt.show()
plt.plot(output_cnn[3,start:end])
plt.plot(output_cnn[2,start:end]) 
plt.show()
plt.plot(output_cnn[5,start:end])
plt.plot(output_cnn[4,start:end])
plt.show()

# %%
plt.plot(dataset[100:500,1])

# %%
plt.plot(dataset[100:500,2])

# %%
plt.plot(dataset[:,3])

# %%
plt.plot(dataset[:,4])

# %%
plt.plot(dataset[:,5])

# %%
plt.plot(dataset[:,6])

# %%
import os
import glob
import scipy.io as sio
